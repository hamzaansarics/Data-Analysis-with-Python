# %%
import numpy as np
import pandas as pd
# %matplotlib --list
# %matplotlib qt
import matplotlib.pyplot as plt
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
df=pd.read_csv(r'I:\Text Datasets\CSV\avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.sort_index(inplace=True)
albany_df=df[df.region=='Albany']

# %%
albany_df['albany25ma']=albany_df['AveragePrice'].rolling(25).mean()
# Out:
# C:\Users\Hamza\AppData\Local\Continuum\anaconda3\envs\cool\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
graph_df=pd.DataFrame()
for region in df['region'].unique():
#     print(region)
    region_df=df.copy()[df.region==region]
    region_df['average25ma']=region_df['AveragePrice'].rolling(25).mean()
    if graph_df.empty:
        graph_df=region_df[['average25ma']]
#     else:
#         graph_df=graph_df.join(region_df[['AveragePrice']])

# %%
new_graph=pd.DataFrame()

# %%
graph_df.dropna().plot(figsize=(10,5))

# %%
df=pd.read_csv('I:\Text Datasets\CSV\Minimum Wage Data.csv',encoding='latin')

# %%
emp_df=pd.DataFrame()

# %%
df.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
emp_graph=pd.DataFrame()
for name,group in df.groupby('State'):
    if emp_graph.empty:
        emp_graph=group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018':name})
    else:
        emp_graph=emp_graph.join(group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018':name}))

# %%
emp_graph.loc[:,['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware']].mean().plot(figsize=(10,5))
plt.scatter([0,1,2,3,4,5,6,7],emp_graph.loc[:,['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware']].mean())

# %%
emp_graph.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.018638 -0.377934    0.717653 -0.129332
# Arizona         NaN  0.018638  1.000000  0.089395    0.498994  0.742527
# Arkansas        NaN -0.377934  0.089395  1.000000   -0.234367  0.135749
# California      NaN  0.717653  0.498994 -0.234367    1.000000  0.483313
#
#             Connecticut  Delaware  District of Columbia  Federal (FLSA)  ...  \
# Alabama             NaN       NaN                   NaN             NaN  ...
# Alaska         0.680886  0.258997              0.321785        0.637679  ...
# Arizona        0.458163  0.429836              0.590848       -0.049914  ...
# Arkansas       0.047580  0.016125              0.266889        0.117245  ...
# California     0.876215  0.479197              0.596865        0.371966  ...
#
# ...

# %%
emp_graph=emp_graph.replace(0,np.NaN).dropna(axis=1)

# %%
emp_graph.corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
# ...

# %%
plt.matshow(emp_graph.corr())

# %%
labels=[e[:2] for e in emp_graph.columns]

# %%
# plt.matshow(emp_graph.corr())
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.matshow(emp_graph.corr(),cmap=plt.cm.RdYlGn)
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
plt.show()

# %%
data=emp_graph.Alaska.to_dict()

# %%
df=pd.read_csv('I:\Text Datasets\CSV\Minimum Wage Data.csv',encoding='latin')

# %%
df.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
emp_df=pd.DataFrame()

# %%
df.set_index('Year',inplace=True)

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
for name,group in df.groupby('State'):
    if emp_df.empty:
        emp_df=group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018':name})
    else:
        emp_df=emp_df.join(group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018':name}))

# %%
emp_df=emp_df.replace(0,np.NaN).dropna(axis=1)
emp_df.corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
# ...

# %%
emp_df.head()
# Out:
#       Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Year
# 1968   15.12      1.12       11.88      7.20        10.08      9.00
# 1969   14.33      1.07       11.26      6.83         9.56      8.53
# 1970   13.54      7.09       10.64      6.45        10.32      8.06
# 1971   12.99      6.80       10.20      6.18         9.89      7.73
# 1972   12.57      7.19        9.88      5.99        11.08      9.58
#
#       District of Columbia  Federal (FLSA)   Guam  Hawaii  ...  Pennsylvania  \
# Year                                                       ...
# 1968                  9.00            8.28   9.00    9.00  ...          8.28
# 1969                  8.53            7.85   8.53    8.53  ...          7.85
# 1970                 10.32            8.38  10.32   10.32  ...          8.38
# 1971                  9.89            8.04   9.89    9.89  ...          8.04
# 1972                  9.58            9.58  11.38    9.58  ...          9.58
#
# ...

# %%
def get_min_wage(year,state):
    try:
        return emp_df.loc[year,state]
    except:
        return np.NaN
get_min_wage(1968,'Colorado')
# Out:
# 7.2

# %%
emp_df.head()
# Out:
#       Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Year
# 1968   15.12      1.12       11.88      7.20        10.08      9.00
# 1969   14.33      1.07       11.26      6.83         9.56      8.53
# 1970   13.54      7.09       10.64      6.45        10.32      8.06
# 1971   12.99      6.80       10.20      6.18         9.89      7.73
# 1972   12.57      7.19        9.88      5.99        11.08      9.58
#
#       District of Columbia  Federal (FLSA)   Guam  Hawaii  ...  Pennsylvania  \
# Year                                                       ...
# 1968                  9.00            8.28   9.00    9.00  ...          8.28
# 1969                  8.53            7.85   8.53    8.53  ...          7.85
# 1970                 10.32            8.38  10.32   10.32  ...          8.38
# 1971                  9.89            8.04   9.89    9.89  ...          8.04
# 1972                  9.58            9.58  11.38    9.58  ...          9.58
#
# ...

# %%
emp_df.loc[1968,'Alaska']
# Out:
# 15.12

# %%
us_county=pd.read_csv(r'I:\Text Datasets\CSV\Sales_April_2019.csv')

# %%
S
